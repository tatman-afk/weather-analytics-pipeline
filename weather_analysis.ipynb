# %%
import requests
import pandas as pd

url = "https://dikgnfpahgrjqpikcvwe.supabase.co/rest/v1/daily_weather_summary"

headers = {
    "apikey": "sb_publishable_NZAjbo2jVL_sddfU7oeVPg_tMyQyfqJ",
    "Authorization": "Bearer sb_publishable_NZAjbo2jVL_sddfU7oeVPg_tMyQyfqJ"
}

response = requests.get(url, headers=headers)
response.raise_for_status()

df = pd.DataFrame(response.json())
df["day"] = pd.to_datetime(df["day"])

df
# Out:
#          day   avg_temp  max_temp  min_temp
# 0 2026-02-10  66.993333      72.5     64.13

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))

plt.plot(
    df["day"],
    df["avg_temp"],
    marker="o",
    linewidth=2,
    label="Average Temperature"
)

plt.fill_between(
    df["day"],
    df["min_temp"],
    df["max_temp"],
    alpha=0.3,
    label="Daily Min–Max Range"
)

plt.title("Daily Temperature Summary (Tucson, AZ)")
plt.xlabel("Date")
plt.ylabel("Temperature (°F)")
plt.legend()
plt.grid(True)

plt.show()
